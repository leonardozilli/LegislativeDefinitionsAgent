# %%
import xml.etree.ElementTree as ET
from pathlib import Path
import re
import csv

NAMESPACES = {
    'EurLex': {'akn': 'http://docs.oasis-open.org/legaldocml/ns/akn/3.0'},
    'Normattiva': {'akn': 'http://docs.oasis-open.org/legaldocml/ns/akn/3.0'},
    'PDL': {'akn': 'http://docs.oasis-open.org/legaldocml/ns/akn/3.0/WD17'}
}

# %%
p = '/home/leo/Desktop/dhdk/Master thesis/.project/data/datasets/PDL_18-19/18PDL0001700_PD.xml'
p = '/home/leo/Desktop/dhdk/Master thesis/.project/data/datasets/Normattiva/20201128_20G00181_VIGENZA_20220101.xml'
p = '/home/leo/Desktop/dhdk/Master thesis/.project/data/datasets/EurLex/32010L0035.xml'

tree = ET.parse(p) 
root = tree.getroot() 
namespace = NAMESPACES['EurLex']
definition = root.find(".//akn:definition", namespace)

definition_head = definition.find('.//akn:definitionHead', namespace)
definition_body_elements = definition.findall('.//akn:definitionBody', namespace)

definendum_id = definition_head.attrib.get('href', '')
#definendum = root.find(f".//akn:def[@eId='{definendum_id}']", namespace).text

full_def = root.find(f".//*[@defines='{definendum_id}']")
"".join(full_def.itertext())

# %%
NAMESPACES = {
    'EurLex': {'akn': 'http://docs.oasis-open.org/legaldocml/ns/akn/3.0'},
    'Normattiva': {'akn': 'http://docs.oasis-open.org/legaldocml/ns/akn/3.0'},
    'PDL': {'akn': 'http://docs.oasis-open.org/legaldocml/ns/akn/3.0/WD17'}
}


def checkXML(xmlfile, dataset):
    tree = ET.parse(xmlfile)
    root = tree.getroot()
    namespace = NAMESPACES[dataset]

    definitions_el = root.findall('.//akn:definitions', namespace)
    if definitions_el:
        return True
    else:
        return False


datasets = ['EurLex', 'Normattiva', 'PDL']

for dataset in datasets:
    extracted, er, c = 0, 0, 0
    target = Path('../data/datasets/' + dataset)

    for file in target.rglob('*.xml'):
        c += 1
        try:
            definitions = checkXML(file, dataset)
            if definitions:
                extracted += 1
        except Exception as e:
            #print(e, file)
            er += 1
            continue

    print(f'{dataset}: found definitions in {extracted} out of {c} files. {er} errors')
# Out:
# EurLex: found definitions in 889 out of 15283 files. 0 errors
# Normattiva: found definitions in 401 out of 3195 files. 0 errors
# PDL: found definitions in 78 out of 3709 files. 0 errors

# %%
def parseXML(xmlfile, dataset):
    tree = ET.parse(xmlfile)
    root = tree.getroot()
    namespace = NAMESPACES[dataset]

    definitions_el = root.findall('.//akn:definitions', namespace)
    if not definitions_el:
        return None

    definitions = []
    for definition in root.findall('.//akn:definition', namespace):
        try:
            definendum, definiens, references, full_def = parse_definition(definition, root, namespace)
            definitions.append({
                'def_n': definition.find('.//akn:definitionHead', namespace).attrib.get('href', ''),
                'label': definition.find('.//akn:definitionHead', namespace).attrib.get('refersTo', ''),
                'definendum': clean_definendum(definendum),
                'definiens': clean_definiens(definiens),
                'full_definition': clean_full_def(full_def),
                'references': references,
                'provenance': dataset,
                'document': xmlfile.name
            })
        except Exception as e:
            print(xmlfile, e, definition.attrib.get('refersTo', ''))
    return definitions


def parse_definition(definition, root, namespace):
    """Extracts definendum, definiens, and references from a single definition."""
    definition_head = definition.find('.//akn:definitionHead', namespace)
    definition_body_elements = definition.findall('.//akn:definitionBody', namespace)

    definendum_id = definition_head.attrib.get('href', '').lstrip('#')
    definendum = root.find(f".//akn:def[@eId='{definendum_id}']", namespace).text
    
    try:
        full_def = "".join(root.find(f".//*[@defines='#{definendum_id}']").itertext())
    except Exception as e:
        full_def = None

    definiens = []
    references = []
    for body in definition_body_elements:
        body_text, body_references = extract_body_and_references(body, root, namespace)
        definiens.append(body_text)
        references.extend(body_references)

    return definendum, ' '.join(definiens), references, full_def


def extract_body_and_references(body, root, namespace):
    """Extracts text and references from a single definition body."""
    body_id = body.attrib.get('href', '').lstrip('#')
    body_element = root.find(f".//akn:defBody[@eId='{body_id}']", namespace)
    body_text = ''.join(body_element.itertext())
    references = [
        ref.attrib.get('href', '') for ref in body_element.findall('.//akn:ref', namespace)
    ]
    return body_text, references


def clean_definendum(text: str):
    text = text.strip()
    if text.startswith(("«", "\'", "\"")) and text.endswith(("»", "\'", "\"")):
        text = text[1:-1]

    return text.strip()


def clean_definiens(text: str):
    if text.startswith(':'):
        text = text.lstrip(':')
    if text.startswith(','):
        text = text.lstrip(',')

    text = text.strip().replace('\n', ' ')
    text = re.sub(r'\s+', ' ', text)

    return text


def clean_full_def(text: str):
    text = text.strip().replace('\n', ' ')
    text = re.sub(r'\s+', ' ', text)
    text = text.replace('""', '')
    
    return text

def save_definitions(definitions, output_file):
    Path(output_file).parent.mkdir(parents=True, exist_ok=True)
    Path(output_file).touch()
    with open(output_file, 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=definitions[0].keys(), delimiter="\t", quoting=csv.QUOTE_MINIMAL)
        writer.writeheader()
        for row in definitions:
            writer.writerow(row)

# %%
# single file test

t = '/home/leo/Desktop/dhdk/Master thesis/.project/data/datasets/Normattiva/20210227_21G00022_VIGENZA_20240101.xml'
t2 = '/home/leo/Desktop/dhdk/Master thesis/.project/data/datasets/EurLex/32014L0049.xml'
t3 = '/home/leo/Desktop/dhdk/Master thesis/.project/data/datasets/EurLex/32021R0403.xml'
t4 = '/home/leo/Desktop/dhdk/Master thesis/.project/data/datasets/EurLex/32010L0035.xml'
t5 = '/home/leo/Desktop/dhdk/Master thesis/.project/data/datasets/EurLex/32018R0545.xml'

definitions = parseXML(Path(t5), 'EurLex')

#save_definitions(definitions, '/home/leo/Desktop/dhdk/Master thesis/.project/data/definitions/definitions.tsv')
definitions

# %% [markdown]
# <div class="alert">
#   <p>Do we need to format the lists (e.g. with (a), (b), etc.)?? Can it be beneficial to RAG?</p>
# </div>

# %% [markdown]
# Ciao Michele, due dubbi:
# 1. Forse ne avevamo già parlato ma quello non c'è un dataset migliore per EurLex? Perché ci sono errori di annotazione abbastanza importanti (tipo blocchi di definizioni con attributo Source "unibio" che vanno ad interferire con altri blocchi con Source "unibo", questo in 72 casi, oppure definizioni che a causa della presenza di virgolette singole e doppie (e.g. ‘status free from “disease”  ’ means a disease-free status of...) sono uscite annotate male e risultano come stringhe vuote).
# 2. Conviene fare gli embedding di definendum e definiens ("x means y") o di separarli (o quantomeno di fare l'embedding dei definendi e della stringa completa in due db diversi)?

# %%
datasets = ['EurLex', 'Normattiva', 'PDL']

extracted, er, c = 0, 0, 0
for dataset in datasets:
    target = Path('../data/datasets/' + dataset)

    for file in target.rglob('*.xml'):
        c += 1
        try:
            definitions = parseXML(file, dataset)
            if definitions:
                extracted += 1
                save_definitions(definitions, Path('../data/definitions') / file.name.replace('.xml', '.tsv'))
        except Exception as e:
            #print(e, file)
            er += 1
            continue

print(f'extracted definitions from {extracted} files. {er} errors out of {c} files.')
# Out:
# ../data/datasets/EurLex/32014L0040.xml 'NoneType' object has no attribute 'text' #roll-your-ownTobacco
# ../data/datasets/EurLex/32021R1173.xml 'NoneType' object has no attribute 'text' #high-endSupercomputer
# ../data/datasets/EurLex/32021R1173.xml 'NoneType' object has no attribute 'text' #hyper-connected
# ../data/datasets/EurLex/32021R1173.xml 'NoneType' object has no attribute 'text' #industrial-gradeSupercomputer
# ../data/datasets/EurLex/32021R1173.xml 'NoneType' object has no attribute 'text' #mid-rangeSupercomputer
# ../data/datasets/EurLex/32010R1061.xml 'NoneType' object has no attribute 'text' #left-onMode
# ../data/datasets/EurLex/32010R1061.xml 'NoneType' object has no attribute 'text' #end-user
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' detectionRisk
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' accreditation
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' verifier
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' verification
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' materialMisstatement
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' operator
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' scopeOfAccreditation
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' competence
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' materialityLevel
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' controlSystem
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' controlActivities
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'text' non-conformity
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' site
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' controlEnvironment
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' inherentRisk
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' controlRisk
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' verificationRisk
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' reasonableAssurance
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' analyticalProcedures
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' internalVerificationDocumentation
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' EUEtsLeadAuditor
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' EUEtsAuditor
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' technicalExpert
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' levelOfAssurance
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' assessor
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' leadAssessor
# ../data/datasets/EurLex/32012R0600.xml 'NoneType' object has no attribute 'itertext' misstatement
# ../data/datasets/EurLex/32019R0429.xml 'NoneType' object has no attribute 'itertext' scheme
# ../data/datasets/EurLex/32019R0429.xml 'NoneType' object has no attribute 'itertext' applicant
# ../data/datasets/EurLex/32019R0429.xml 'NoneType' object has no attribute 'itertext' schemeOwners
# ../data/datasets/EurLex/32019R0429.xml 'NoneType' object has no attribute 'itertext' economicOperatorsParticipatingInTheScheme
# ../data/datasets/EurLex/32019R0429.xml 'NoneType' object has no attribute 'itertext' OECDMethodology
# ../data/datasets/EurLex/32019R0429.xml 'NoneType' object has no attribute 'itertext' overarchingDueDiligencePrinciples
# ../data/datasets/EurLex/32019R0429.xml 'NoneType' object has no attribute 'itertext' repeatApplication
# ../data/datasets/EurLex/32019R0429.xml 'NoneType' object has no attribute 'itertext' generalConditionsForRecognition
# ../data/datasets/EurLex/32019R0429.xml 'NoneType' object has no attribute 'itertext' specificCriteriaForAssessment
# ../data/datasets/EurLex/32016L1629.xml 'NoneType' object has no attribute 'text' #high-speedVessel
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' slaughterhouse
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' frogs
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' snails
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' insects
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' reeferVessel
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' freezerVessel
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' factoryVessel
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' dispatchCentre
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'text' game-handlingEstablishment
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' cuttingPlant
# ../data/datasets/EurLex/32020R2235.xml 'NoneType' object has no attribute 'itertext' sprouts
# ../data/datasets/EurLex/32018R1672.xml 'NoneType' object has no attribute 'text' #bearer-negotiableInstruments
# ../data/datasets/EurLex/32017R2402.xml 'NoneType' object has no attribute 'text' #asset-backedCommercialPaperProgramme
# ../data/datasets/EurLex/32017R2402.xml 'NoneType' object has no attribute 'text' #asset-backedCommercialPaperTransaction
# ../data/datasets/EurLex/32017R2402.xml 'NoneType' object has no attribute 'text' #fully-SupportedAbcpProgramme
# ../data/datasets/EurLex/32014R1163.xml 'NoneType' object has no attribute 'text' #fee-payingCreditInstitution
# ../data/datasets/EurLex/32014R1163.xml 'NoneType' object has no attribute 'text' #fee-payingBranch
# ../data/datasets/EurLex/32014R1163.xml 'NoneType' object has no attribute 'text' #groupOfFee-PayingEntities
# ../data/datasets/EurLex/32019R0006.xml 'NoneType' object has no attribute 'text' #pre-clinicalStudy
# ../data/datasets/EurLex/32019R0006.xml 'NoneType' object has no attribute 'text' #benefit-riskBalance
# ../data/datasets/EurLex/32010R1060.xml 'NoneType' object has no attribute 'text' #compression-typeRefrigeratingAppliance
# ../data/datasets/EurLex/32010R1060.xml 'NoneType' object has no attribute 'text' #absorption-typeRefrigeratingAppliance
# ../data/datasets/EurLex/32010R1060.xml 'NoneType' object has no attribute 'text' #refrigerator-freezer
# ../data/datasets/EurLex/32010R1060.xml 'NoneType' object has no attribute 'text' #frozen-foodStorageCabinet
# ../data/datasets/EurLex/32010R1060.xml 'NoneType' object has no attribute 'text' #multi-useAppliance
# ../data/datasets/EurLex/32010R1060.xml 'NoneType' object has no attribute 'text' #end-user
# ../data/datasets/EurLex/32015R0035.xml 'NoneType' object has no attribute 'text' basicRisk-FreeInterestRateTermStructure
# ../data/datasets/EurLex/32015R0035.xml 'NoneType' object has no attribute 'text' non-regulatedUndertaking
# ../data/datasets/EurLex/32015R0035.xml 'NoneType' object has no attribute 'text' non-regulatedUndertakingCarryingOutFinancialActivities
# ../data/datasets/EurLex/32015R0208.xml 'NoneType' object has no attribute 'text' #InteriorRear-ViewMirror
# ../data/datasets/EurLex/32015R0208.xml 'NoneType' object has no attribute 'text' #ClassOfRear-ViewMirror
# ../data/datasets/EurLex/32010R1151.xml 'NoneType' object has no attribute 'text' #questionnaire-basedData
# ../data/datasets/EurLex/32012R0601.xml 'NoneType' object has no attribute 'text' #tonne-kilometre
# ../data/datasets/EurLex/32021R1153.xml 'NoneType' object has no attribute 'text' #dual-useInfrastructure
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' UnionRailSystem
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' infrastructureManager
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' railwayUndertaking
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' nationalSafetyAuthority
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' nationalRules
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' safetyManagementSystem
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' investigator-in-charge
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' accident
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' seriousAccident
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' incident
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' investigation
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' causes
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' lightRail
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' conformityAssessmentBody
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' interoperabilityConstituents
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' keeper
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' vehicle
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' manufacturer
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' consignor
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' consignee
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' loader
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' unloader
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' filler
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' unfiller
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' carrier
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' contractingEntity
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' typeOfOperation
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' extentOfOperation
# ../data/datasets/EurLex/32016L0798.xml 'NoneType' object has no attribute 'itertext' areaOfOperation
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' Fan
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' Impeller
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' AxialFan
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' OrificePanel
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' OrificeRing
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' CentrifugalFan
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' CentrifugalRadialBladedFan
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' CentrifugalForwardCurvedFan
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' CentrifugalBackwardCurvedFanWithoutHousing
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' Housing
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' CentrifugalBackwardCurvedFanWithHousing
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' CrossFlowFan
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' MixedFlowFan
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' Short-timeDuty
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' VentilationFan
# ../data/datasets/EurLex/32011R0327.xml 'NoneType' object has no attribute 'itertext' specificRatio
# ../data/datasets/EurLex/32015R0758.xml 'NoneType' object has no attribute 'text' #in-vehicleEquipment
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' resolution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' creditInstitution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' investmentFirm
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' financialInstitution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' subsidiary
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' parentUndertaking
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' consolidatedBasis
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' institutionalProtectionScheme
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' financialHoldingCompany
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' mixedFinancialHoldingCompany
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'text' mixed-activityHoldingCompany
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' parentFinancialHoldingCompanyInAMemberState
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' UnionParentFinancialHoldingCompany
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' parentMixedFinancialHoldingCompanyInAMemberState
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' UnionParentMixedFinancialHoldingCompany
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' resolutionObjectives
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' branch
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' resolutionAuthority
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' resolutionTool
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' resolutionPower
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' competentAuthority
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' competentMinistries
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' institution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' managementBody
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' seniorManagement
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' group
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'text' cross-borderGroup
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' extraordinaryPublicFinancialSupport
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' emergencyLiquidityAssistance
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' systemicCrisis
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' groupEntity
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' recoveryPlan
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' groupRecoveryPlan
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' significantBranch
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' criticalFunctions
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' coreBusinessLines
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' consolidatingSupervisor
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' ownFunds
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' conditionsForResolution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' resolutionAction
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' resolutionPlan
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' groupResolution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' groupResolutionPlan
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'text' group-levelResolutionAuthority
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' groupResolutionScheme
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' resolutionCollege
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' normalInsolvencyProceedings
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' parentInstitutionInAMemberState
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' UnionParentInstitution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' ownFundsRequirements
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' supervisoryCollege
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' UnionStateAidFramework
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' windingUp
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' assetSeparationTool
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' assetManagementVehicle
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'text' bail-inTool
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' saleOfBusinessTool
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' bridgeInstitution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' bridgeInstitutionTool
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' instrumentsOfOwnership
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' shareholders
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' transferPowers
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' centralCounterparty
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'text' write-downAndConversionPowers
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' securedLiability
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' CommonEquityTier1Instruments
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' AdditionalTier1Instruments
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' aggregateAmount
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' eligibleLiabilities
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' depositGuaranteeScheme
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' Tier2Instruments
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' conversionRate
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' affectedCreditor
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' affectedHolder
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' appropriateAuthority
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' relevantParentInstitution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' recipient
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' businessDay
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' terminationRight
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' institutionUnderResolution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' UnionSubsidiary
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' UnionParentUndertaking
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' third-countryInstitution
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' third-countryParentUndertaking
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' third-countryResolutionProceedings
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' UnionBranch
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'text' relevantThird-CountryAuthority
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' groupFinancingArrangement
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' back-to-backTransaction
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'text' intra-groupGuarantee
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' coveredDeposits
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' eligibleDeposits
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' coveredBond
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' titleTransferFinancialCollateralArrangement
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' nettingArrangement
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'text' set-offArrangement
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' crisisPreventionMeasure
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' crisisManagementMeasure
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' recoveryCapacity
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' depositor
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' investor
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' designatedNationalMacroprudentialAuthority
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' micro
# ../data/datasets/EurLex/32014L0059.xml 'NoneType' object has no attribute 'itertext' regulatedMarket
# ../data/datasets/EurLex/32011R0582.xml 'NoneType' object has no attribute 'text' #criticalEmission-RelatedMaintenance
# ../data/datasets/EurLex/32011R0582.xml 'NoneType' object has no attribute 'text' #non-emission-relatedMaintenance
# ../data/datasets/EurLex/32011R0582.xml 'NoneType' object has no attribute 'text' #scan-tool
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' researchInfrastructures
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' smartSpecialisationStrategy
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' EuropeanPartnership
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' openAccess
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' openScience
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' mission
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' pre-commercialProcurement
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' publicProcurementOfInnovativeSolutions
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' accessRights
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' background
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' dissemination
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' exploitation
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' fairAndReasonableConditions
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' fundingBody
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' internationalEuropeanResearchOrganisation
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' legalEntity
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' wideningCountries
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'text' non-profitLegalEntity
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' smallOrMedium-SizedEnterprise
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'text' smallMid-Cap
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' results
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' researchOutput
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' SealOfExcellence
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' MeansAnImplementingActLayingOutAStrategyForRealisingContentInTheWorkProgrammeCoveringAMaximumPeriodOfFourYears
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' workProgramme
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' contract
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' reimbursableAdvance
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' classifiedInformation
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' blendingOperation
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' HorizonEuropeBlendedFinance
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' EICBlendedFinance
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' researchAndInnovationAction
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' innovationAction
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' ERCFrontierResearchAction
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' trainingAndMobilityAction
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' programmeCo-FundAction
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'text' pre-commercialProcurementAction
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' publicProcurementOfInnovativeSolutionsAction
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' coordinationAndSupportAction
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' inducementPrize
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' recognitionPrize
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' innovationAndMarketDeploymentAction
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' indirectActions
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' directActions
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' procurement
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' affiliatedEntity
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' innovationEcosystem
# ../data/datasets/EurLex/32021R0695.xml 'NoneType' object has no attribute 'itertext' project-basedRemuneration
# ../data/datasets/EurLex/32019R2014.xml 'NoneType' object has no attribute 'text' #built-inHouseholdWasher-Dryer
# ../data/datasets/EurLex/32019R2014.xml 'NoneType' object has no attribute 'text' #multi-drumHouseholdWasher-Dryer
# ../data/datasets/EurLex/32019R0631.xml 'NoneType' object has no attribute 'text' #EUFleet-WideTarget
# ../data/datasets/EurLex/32019R0631.xml 'NoneType' object has no attribute 'text' #zero-AndLow-EmissionVehicle
# ../data/datasets/EurLex/32019R0856.xml 'NoneType' object has no attribute 'text' #small-scaleProject
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsAuthorities
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsLegislation
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsControls
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' person
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' economicOperator
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsRepresentative
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' risk
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsFormalities
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' entrySummaryDeclaration
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' exitSummaryDeclaration
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' temporaryStorageDeclaration
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsDeclaration
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' re-exportDeclaration
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' re-exportNotification
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' declarant
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsProcedure
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' temporaryStorage
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsDebt
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' debtor
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' importDuty
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' exportDuty
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsStatus
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' UnionGoods
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'text' non-UnionGoods
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' riskManagement
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' releaseOfGoods
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' customsSupervision
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' repayment
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' remission
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' processedProducts
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' personEstablishedInTheCustomsTerritoryOfTheUnion
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' permanentBusinessEstablishment
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' presentationOfGoodsToCustoms
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' holderOfTheGoods
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' holderOfTheProcedure
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' commercialPolicyMeasures
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' processingOperations
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' rateOfYield
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' decision
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' carrier
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext'
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext'
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' WhereTheActiveMeansOfTransportLeavingTheCustomsTerritoryOfTheUnionIsOnlyTransportingAnotherMeansOfTransportWhich
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext'
# ../data/datasets/EurLex/32013R0952.xml 'NoneType' object has no attribute 'itertext' buyingCommission
# ../data/datasets/EurLex/32019R2023.xml 'NoneType' object has no attribute 'text' #built-inHouseholdWasher-Dryer
# ../data/datasets/EurLex/32019R2023.xml 'NoneType' object has no attribute 'text' #multi-drumHouseholdWasher-Dryer
# ../data/datasets/EurLex/32019R2024.xml 'NoneType' object has no attribute 'text' #sub-compartment
# ../data/datasets/EurLex/32021R1059.xml 'NoneType' object has no attribute 'text' #cross-borderLegalBody
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' AIFs
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' AIFMs
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' carriedInterest
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' closeLinks
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' competentAuthorities
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' competentAuthoritiesOfTheEuAif
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' control
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' established
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' EUAif
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' EUAifm
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' feederAif
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' financialInstrument
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' holdingCompany
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' homeMemberStateOfTheAif
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' hostMemberStateOfTheAifm
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' initialCapital
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' issuer
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' legalRepresentative
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' leverage
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' managingAifs
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' marketing
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' masterAif
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' MemberStateOfReference
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'text' non-EUAif
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'text' non-EUAifm
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'text' non-listedCompany
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' ownFunds
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' parentUndertaking
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' primeBroker
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' professionalInvestor
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' qualifyingHolding
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' employees
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' retailInvestor
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' subsidiary
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' securitisationSpecialPurposeEntities
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'itertext' UCITS
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'text' #non-EUAif
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'text' #non-EUAifm
# ../data/datasets/EurLex/32011L0061.xml 'NoneType' object has no attribute 'text' #non-listedCompany
# ../data/datasets/EurLex/32014L0065.xml 'NoneType' object has no attribute 'text' #high-frequencyAlgorithmicTradingTechnique
# ../data/datasets/EurLex/32014L0065.xml 'NoneType' object has no attribute 'text' #cross-sellingPractice
# ../data/datasets/EurLex/32014L0065.xml 'NoneType' object has no attribute 'text' #third-countryFirm
# ../data/datasets/EurLex/32014R0596.xml 'NoneType' object has no attribute 'text' #buy-backProgramme
# ../data/datasets/EurLex/32014R0596.xml 'NoneType' object has no attribute 'text' #stake-building
# ../data/datasets/EurLex/32014R0596.xml 'NoneType' object has no attribute 'text' #high-frequencyTrading
# ../data/datasets/EurLex/32015R1189.xml 'NoneType' object has no attribute 'text' #non-woodyBiomassBoiler
# ../data/datasets/EurLex/32018R0161.xml 'NoneType' object has no attribute 'text' #GFCMGeographicalSub-Area
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' channel
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' 8
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' radio
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' centralRegister
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' 8
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' frequencyAssignment
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' operator
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' StateAircraft
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' offsetCarrierOperation
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' aircraftRadioEquipment
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' radioUpgrade
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' designatedOperationalCoverage
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'text' radio-telephony
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' letterOfAgreement
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'text' transport-typeStateAircraft
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' airportOperator
# ../data/datasets/EurLex/32012R1079.xml 'NoneType' object has no attribute 'itertext' operationalControlCommunication
# ../data/datasets/EurLex/32014R0651.xml 'NoneType' object has no attribute 'text' smallAndMedium-SizedEnterprises
# ../data/datasets/EurLex/32014R0651.xml 'NoneType' object has no attribute 'text' in-kindContribution
# ../data/datasets/EurLex/32014R0651.xml 'NoneType' object has no attribute 'text' follow-onInvestment
# ../data/datasets/EurLex/32014R0651.xml 'NoneType' object has no attribute 'text' high-efficiencyCogeneration
# ../data/datasets/EurLex/32014R0651.xml 'NoneType' object has no attribute 'text' re-use
# ../data/datasets/EurLex/32015R2365.xml 'NoneType' object has no attribute 'text' #non-financialCounterparty
# ../data/datasets/EurLex/32015R0760.xml 'NoneType' object has no attribute 'text' #quasi-equity
# ../data/datasets/EurLex/32013R0811.xml 'NoneType' object has no attribute 'text' #back-upImmersionHeater
# ../data/datasets/EurLex/32021R1232.xml 'NoneType' object has no attribute 'text' #number-independentInterpersonalCommunicationsService
# ../data/datasets/EurLex/32014L0094.xml 'NoneType' object has no attribute 'itertext' alternativeFuels
# ../data/datasets/EurLex/32014L0094.xml 'NoneType' object has no attribute 'itertext' electricVehicle
# ../data/datasets/EurLex/32014L0094.xml 'NoneType' object has no attribute 'itertext' rechargingPoint
# ../data/datasets/EurLex/32014L0094.xml 'NoneType' object has no attribute 'itertext' normalPowerRechargingPoint
# ../data/datasets/EurLex/32014L0094.xml 'NoneType' object has no attribute 'itertext' highPowerRechargingPoint
# ../data/datasets/EurLex/32014L0094.xml 'NoneType' object has no attribute 'text' shore-sideElectricitySupply
# ../data/datasets/EurLex/32014L0094.xml 'NoneType' object has no attribute 'itertext' rechargingOrRefuellingPointAccessibleToThePublic
# ../data/datasets/EurLex/32014L0094.xml 'NoneType' object has no attribute 'itertext' refuellingPoint
# ../data/datasets/EurLex/32014L0094.xml 'NoneType' object has no attribute 'itertext' refuellingPointForLng
# ../data/datasets/EurLex/32013R0543.xml 'NoneType' object has no attribute 'text' #cut-offTime
# ../data/datasets/EurLex/32016R1628.xml 'NoneType' object has no attribute 'text' #EUType-Approval
# ../data/datasets/EurLex/32016R1628.xml 'NoneType' object has no attribute 'text' #single-fuelEngine
# ../data/datasets/EurLex/32016R1628.xml 'NoneType' object has no attribute 'text' #constant-speedEngine
# ../data/datasets/EurLex/32016R1628.xml 'NoneType' object has no attribute 'text' #variable-speedEngine
# ../data/datasets/EurLex/32016R1628.xml 'NoneType' object has no attribute 'text' #steady-stateTestCycle
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' slaughterhouse
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' holdingOfProvenance
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' productionArea
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' relayingArea
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' staffDesignatedByTheCompetentAuthorities
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' riskAnalysis
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' cuttingPlant
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' poultry
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' lagomorphs
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' foodBusinessOperator
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' domesticUngulates
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' meat
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' farmedGame
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' finalConsumer
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' retail
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' establishment
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'text' Low-capacitySlaughterhouse
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'text' Low-capacityGame-HandlingEstablishment
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' livestockUnit
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' smallWildGame
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'text' game-handlingEstablishment
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' dispatchCentre
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' bivalveMolluscs
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' processing
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' viscera
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' primaryProduction
# ../data/datasets/EurLex/32019R0624.xml 'NoneType' object has no attribute 'itertext' milkProductionHolding
# ../data/datasets/EurLex/32021R0691.xml 'NoneType' object has no attribute 'text' #self-employedPerson
# ../data/datasets/EurLex/32021R0696.xml 'NoneType' object has no attribute 'text' #near-EarthObjects
# ../data/datasets/EurLex/32021R0696.xml 'NoneType' object has no attribute 'text' #CopernicusThird-PartyDataAndInformation
# ../data/datasets/EurLex/32021R0696.xml 'NoneType' object has no attribute 'text' #GOVSATCOMUse-Case
# ../data/datasets/EurLex/32021R0696.xml 'NoneType' object has no attribute 'text' #sensitiveNon-ClassifiedInformation
# ../data/datasets/EurLex/32019R0980.xml 'NoneType' object has no attribute 'text' #asset-backedSecurities
# ../data/datasets/EurLex/32018R0858.xml 'NoneType' object has no attribute 'itertext' type-approval
# ../data/datasets/EurLex/32018R0858.xml 'NoneType' object has no attribute 'itertext' EUType-Approval
# ../data/datasets/EurLex/32018R0858.xml 'NoneType' object has no attribute 'itertext' nationalType-Approval
# ../data/datasets/EurLex/32018R0858.xml 'NoneType' object has no attribute 'itertext' type-approvalCertificate
# ../data/datasets/EurLex/32018R0858.xml 'NoneType' object has no attribute 'itertext' certificateOfConformity
# ../data/datasets/EurLex/32018R0858.xml 'NoneType' object has no attribute 'itertext' individualVehicleApproval
# ../data/datasets/EurLex/32018R0858.xml 'NoneType' object has no attribute 'itertext' whole-vehicleType-Approval
# ../data/datasets/EurLex/32018R0858.xml 'NoneType' object has no attribute 'itertext' multi-stageType-Approval
# ...
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' EUParentMixedFinancialHoldingCompany
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' centralCounterparty
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' participation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' qualifyingHolding
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' control
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' closeLinks
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' groupOfConnectedClients
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' competentAuthority
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' consolidatingSupervisor
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' authorisation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' homeMemberState
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' hostMemberState
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' ESCBCentralBanks
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' centralBanks
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' consolidatedSituation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' consolidatedBasis
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' sub-consolidatedBasis
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' financialInstrument
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' initialCapital
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' operationalRisk
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' dilutionRisk
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' probabilityOfDefault
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' lossGivenDefault
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' conversionFactor
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' creditRiskMitigation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' fundedCreditProtection
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' unfundedCreditProtection
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' cashAssimilatedInstrument
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' securitisation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' securitisationPosition
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' re-securitisation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' re-securitisationPosition
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' creditEnhancement
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' securitisationSpecialPurposeEntity
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' tranche
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' markingToMarket
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' markingToModel
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' independentPriceVerification
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' eligibleCapital
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' recognisedExchange
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' discretionaryPensionBenefits
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' mortgageLendingValue
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' residentialProperty
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' marketValue
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' applicableAccountingFramework
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' one-yearDefaultRate
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' speculativeImmovablePropertyFinancing
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' tradeFinance
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' officiallySupportedExportCredits
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' repurchaseTransaction
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' simpleRepurchaseAgreement
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' positionsHeldWithTradingIntent
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' tradingBook
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' multilateralTradingFacility
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' qualifyingCentralCounterparty
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' defaultFund
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' pre-fundedContributionToTheDefaultFundOfACcp
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' tradeExposure
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' regulatedMarket
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' leverage
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' riskOfExcessiveLeverage
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' creditRiskAdjustment
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' internalHedge
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' referenceObligation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' externalCreditAssessmentInstitution
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' nominatedEcai
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' basicOwnFunds
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' Tier1Own-FundInsuranceItems
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' additionalTier1Own-FundInsuranceItems
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' Tier2Own-FundInsuranceItems
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' Tier3Own-FundInsuranceItems
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' deferredTaxAssetsThatRelyOnFutureProfitability
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' definedBenefitPensionFundAssets
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' distributions
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' indirectHolding
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' otherCapitalInstruments
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' otherReserves
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' ownFunds
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' ownFundsInstruments
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' minorityInterest
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' reciprocalCrossHolding
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' retainedEarnings
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' syntheticHolding
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' cross-guaranteeScheme
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' distributableItems
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' exposure
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' loss
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' expectedLoss
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' ratingSystem
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' typeOfExposures
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' businessUnit
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' largeFinancialSectorEntity
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' unregulatedFinancialSectorEntity
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' obligorGrade
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' facilityGrade
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' servicer
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' lendingInstitution
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' securedLendingTransaction
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' capitalMarket-DrivenTransaction
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' underlyingCiu
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' capitalMarket-DrivenTransaction
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' excessSpread
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' clean-upCallOption
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' liquidityFacility
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' ratingsBasedMethod
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' supervisoryFormulaMethod
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' unratedPosition
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' ratedPosition
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' asset-backedCommercialPaperProgramme
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' traditionalSecuritisation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' syntheticSecuritisation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' revolvingExposure
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' revolvingSecuritisation
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' earlyAmortisationProvision
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' firstLossTranche
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' asset-backedCommercialPaperProgramme
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' counterpartyCreditRisk
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' longSettlementTransactions
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' marginLendingTransactions
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' nettingSet
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' riskPosition
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' hedgingSet
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' marginAgreement
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' marginThreshold
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' marginPeriodOfRisk
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' cross-productNetting
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' distributionOfMarketValues
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' distributionOfExposures
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' risk-neutralDistribution
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' actualDistribution
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' currentExposure
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' peakExposure
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' rolloverRisk
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' contractualCrossProductNettingAgreement
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext'
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' paymentLeg
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' CCP-relatedTransaction
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' clearingMember
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' client
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' financialCustomer
# ../data/datasets/EurLex/32013R0575R(02).xml 'NoneType' object has no attribute 'itertext' retailDeposit
# ../data/datasets/EurLex/32018R0545.xml 'NoneType' object has no attribute 'text' #pre-engagement
# ../data/datasets/EurLex/32018R0545.xml 'NoneType' object has no attribute 'text' #pre-engagementBaseline
# ../data/datasets/EurLex/32013L0034.xml 'NoneType' object has no attribute 'text' #public-interestEntities
# extracted definitions from 1348 files. 0 errors out of 22187 files.

# %% [markdown]
# 72 EurLex documents have a typo in the declaration of the definitions. There are two distinct <definitions> tags that, one of which is sourced to "unibio" and the second to "unibo". Inside of each element, the ids of the definitions start in both cases from 1, resulting in duplicate references.

# %%
# insert tsv into sqlite db
for file in Path('../data/definitions').rglob('*.tsv'):
    with open(file, 'r') as f:
        for line in f:
            try:
                label, showAs, definition_body = line.strip().split('\t')
                #print(label, showAs, definition_body)
            except:
                print(line)

# %%
import sqlite3

def add_definitions(conn, project):
    pass


def populate_sqlite_db(definitions_folder, db_file):
    with sqlite3.connect(db_file) as conn:
        cursor = conn.cursor()
        cursor.execute('''
            CREATE TABLE definitions(
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                project_id INTEGER,
                label TEXT NOT NULL,
                showAs TEXT NOT NULL,
                definition_body TEXT NOT NULL,
                FOREIGN KEY(project_id) REFERENCES projects(id)
            )
        ''')

        for project in definitions_folder.glob('*'):
            project_id = add_project(conn, project)
            for definition_file in project.glob('*.tsv'):
                add_definitions(conn, project_id, definition_file)



with sqlite3.connect('../definitions.db') as conn:
    cursor = conn.cursor()
    sql = ''' INSERT INTO projects(name,begin_date,end_date)
            VALUES(?,?,?) '''

    cursor.execute(insert_statement)
    conn.commit()

# %%
import polars as pl

df = pl.read_csv('../data/definitions/*.tsv', separator='\t')#, has_header=False, schema={'label': pl.Utf8, 'showAs': pl.Utf8, 'definition_body': pl.Utf8}, truncate_ragged_lines=True)
df.head()
# Out:
# shape: (5, 7)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬────────────┬────────────┬─────────────┐
# │ label        ┆ definendum   ┆ definiens    ┆ full_defini ┆ references ┆ provenance ┆ document    │
# │ ---          ┆ ---          ┆ ---          ┆ tion        ┆ ---        ┆ ---        ┆ ---         │
# │ str          ┆ str          ┆ str          ┆ ---         ┆ str        ┆ str        ┆ str         │
# │              ┆              ┆              ┆ str         ┆            ┆            ┆             │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪════════════╪════════════╪═════════════╡
# │ #georeferenz ┆ georeferenzi ┆ tecnica di   ┆ a) georefer ┆ []         ┆ PDL        ┆ 18PDL000147 │
# │ iazione      ┆ azione       ┆ attribuzione ┆ enziazione  ┆            ┆            ┆ 0_PD.xml    │
# │              ┆              ┆ di coo…      ┆ : tecnic…   ┆            ┆            ┆             │
# │ #sistemaInfo ┆ sistema      ┆ sistema      ┆ b) sistema  ┆ []         ┆ PDL        ┆ 18PDL000147 │
# │ rmativoGeogr ┆ informativo  ┆ informatico, ┆ informativo ┆            ┆            ┆ 0_PD.xml    │
# │ afico        ┆ geografico   ┆ hardware …   ┆ geograf…    ┆            ┆            ┆             │
# │ #gestoreDelS ┆ gestore del  ┆ il soggetto  ┆ a) gestore  ┆ []         ┆ PDL        ┆ 18PDL000155 │
# │ ottoprodotto ┆ sottoprodott ┆ pubblico o   ┆ del sottopr ┆            ┆            ┆ 0_PD.xml    │
# │ Umido(…      ┆ o umid…      ┆ privato…     ┆ odotto u…   ┆            ┆            ┆             │
# │ #scartiAlime ┆ scarti       ┆ sottoprodott ┆ b) scarti   ┆ []         ┆ PDL        ┆ 18PDL000155 │
# │ ntari        ┆ alimentari   ┆ i della      ┆ alimentari  ┆            ┆            ┆ 0_PD.xml    │
# │              ┆              ┆ produzione…  ┆ : sottopr…  ┆            ┆            ┆             │
# │ #compostaggi ┆ compostaggio ┆ fermentazion ┆ c) composta ┆ []         ┆ PDL        ┆ 18PDL000155 │
# │ o            ┆              ┆ e della      ┆ ggio : ferm ┆            ┆            ┆ 0_PD.xml    │
# │              ┆              ┆ materia or…  ┆ entazion…   ┆            ┆            ┆             │
# └──────────────┴──────────────┴──────────────┴─────────────┴────────────┴────────────┴─────────────┘

# %%
df.select(pl.len()) # starting len
# Out:
# shape: (1, 1)
# ┌───────┐
# │ len   │
# │ ---   │
# │ u32   │
# ╞═══════╡
# │ 14729 │
# └───────┘

# %% [markdown]
# #### Null filtering

# %%
df.filter(pl.all_horizontal(pl.all().is_null())) # all nulls
# Out:
# shape: (0, 7)
# ┌───────┬────────────┬───────────┬─────────────────┬────────────┬────────────┬──────────┐
# │ label ┆ definendum ┆ definiens ┆ full_definition ┆ references ┆ provenance ┆ document │
# │ ---   ┆ ---        ┆ ---       ┆ ---             ┆ ---        ┆ ---        ┆ ---      │
# │ str   ┆ str        ┆ str       ┆ str             ┆ str        ┆ str        ┆ str      │
# ╞═══════╪════════════╪═══════════╪═════════════════╪════════════╪════════════╪══════════╡
# └───────┴────────────┴───────────┴─────────────────┴────────────┴────────────┴──────────┘

# %%
df.filter(pl.col('definendum').is_null())
# Out:
# shape: (20, 7)
# ┌───────┬────────────┬────────────────┬───────────────┬───────────────┬────────────┬───────────────┐
# │ label ┆ definendum ┆ definiens      ┆ full_definiti ┆ references    ┆ provenance ┆ document      │
# │ ---   ┆ ---        ┆ ---            ┆ on            ┆ ---           ┆ ---        ┆ ---           │
# │ str   ┆ str        ┆ str            ┆ ---           ┆ str           ┆ str        ┆ str           │
# │       ┆            ┆                ┆ str           ┆               ┆            ┆               │
# ╞═══════╪════════════╪════════════════╪═══════════════╪═══════════════╪════════════╪═══════════════╡
# │ #     ┆ null       ┆ juveniles"     ┆ " "           ┆ []            ┆ EurLex     ┆ 32010R0724.xm │
# │       ┆            ┆ means:         ┆ juveniles"    ┆               ┆            ┆ l             │
# │       ┆            ┆                ┆ means:        ┆               ┆            ┆               │
# │       ┆            ┆                ┆ specimen…     ┆               ┆            ┆               │
# │ #     ┆ null       ┆ information"   ┆ (1) " inside  ┆ []            ┆ EurLex     ┆ 32011R1227.xm │
# │       ┆            ┆ means:         ┆ information " ┆               ┆            ┆ l             │
# │       ┆            ┆                ┆ mea…          ┆               ┆            ┆               │
# │ #     ┆ null       ┆ transitional   ┆ " "           ┆ []            ┆ EurLex     ┆ 32012R0284.xm │
# │       ┆            ┆ measures       ┆ transitional  ┆               ┆            ┆ l             │
# │       ┆            ┆ provided…      ┆ measures      ┆               ┆            ┆               │
# │       ┆            ┆                ┆ prov…         ┆               ┆            ┆               │
# │ #     ┆ null       ┆ transitional   ┆ " "           ┆ []            ┆ EurLex     ┆ 32012R0996.xm │
# │       ┆            ┆ measures       ┆ transitional  ┆               ┆            ┆ l             │
# │       ┆            ┆ provided…      ┆ measures      ┆               ┆            ┆               │
# │       ┆            ┆                ┆ prov…         ┆               ┆            ┆               │
# │ #     ┆ null       ┆ low ALs" means ┆ " " low ALs"  ┆ []            ┆ EurLex     ┆ 32013L0035.xm │
# │       ┆            ┆ levels which   ┆ means levels  ┆               ┆            ┆ l             │
# │       ┆            ┆ re…            ┆ whic…         ┆               ┆            ┆               │
# │ …     ┆ …          ┆ …              ┆ …             ┆ …             ┆ …          ┆ …             │
# │ #     ┆ null       ┆ Black Sea"     ┆ " " Black     ┆ ['/akn/eu/act ┆ EurLex     ┆ 32017R0087.xm │
# │       ┆            ┆ means maritime ┆ Sea" means    ┆ /regulation/e ┆            ┆ l             │
# │       ┆            ┆ wate…          ┆ maritime …    ┆ p/20…         ┆            ┆               │
# │ #     ┆ null       ┆ settlement     ┆ " "           ┆ []            ┆ EurLex     ┆ 32017R0389.xm │
# │       ┆            ┆ instruction"   ┆ settlement    ┆               ┆            ┆ l             │
# │       ┆            ┆ means …        ┆ instruction"  ┆               ┆            ┆               │
# │       ┆            ┆                ┆ me…           ┆               ┆            ┆               │
# │ #     ┆ null       ┆ trading venue  ┆ " " trading   ┆ []            ┆ EurLex     ┆ 32017R1005.xm │
# │       ┆            ┆ operator"      ┆ venue         ┆               ┆            ┆ l             │
# │       ┆            ┆ means …        ┆ operator" me… ┆               ┆            ┆               │
# │ #     ┆ null       ┆ composite      ┆ " " composite ┆ []            ┆ EurLex     ┆ 32019R0759.xm │
# │       ┆            ┆ product" means ┆ product"      ┆               ┆            ┆ l             │
# │       ┆            ┆ compo…         ┆ means c…      ┆               ┆            ┆               │
# │ #     ┆ null       ┆ United Kingdom ┆ " " United    ┆ []            ┆ EurLex     ┆ 32020R2227.xm │
# │       ┆            ┆ waters' means  ┆ Kingdom       ┆               ┆            ┆ l             │
# │       ┆            ┆ t…             ┆ waters' mea…  ┆               ┆            ┆               │
# └───────┴────────────┴────────────────┴───────────────┴───────────────┴────────────┴───────────────┘

# %%
df.filter(pl.col('definiens').is_null())
# Out:
# shape: (3, 7)
# ┌───────────────┬──────────────┬───────────┬──────────────┬────────────┬────────────┬──────────────┐
# │ label         ┆ definendum   ┆ definiens ┆ full_definit ┆ references ┆ provenance ┆ document     │
# │ ---           ┆ ---          ┆ ---       ┆ ion          ┆ ---        ┆ ---        ┆ ---          │
# │ str           ┆ str          ┆ str       ┆ ---          ┆ str        ┆ str        ┆ str          │
# │               ┆              ┆           ┆ str          ┆            ┆            ┆              │
# ╞═══════════════╪══════════════╪═══════════╪══════════════╪════════════╪════════════╪══════════════╡
# │ #portaleDeiSe ┆ portale dei  ┆ null      ┆ b) portale   ┆ []         ┆ Normattiva ┆ 20110418_011 │
# │ rviziTelemati ┆ servizi      ┆           ┆ dei servizi  ┆            ┆            ┆ G0087_VIGENZ │
# │ ci            ┆ telematici   ┆           ┆ telemat…     ┆            ┆            ┆ A_2024…      │
# │ #incaricoGliI ┆ «incarico»,  ┆ null      ┆ h)           ┆ []         ┆ Normattiva ┆ 20201215_20G │
# │ ncarichi      ┆ gli          ┆           ┆ «incarico»,  ┆            ┆            ┆ 00190_ORIGIN │
# │               ┆ incarichi    ┆           ┆ gli          ┆            ┆            ┆ ALE.xm…      │
# │               ┆              ┆           ┆ incarichi :  ┆            ┆            ┆              │
# │ #enteCreditiz ┆ ente         ┆ null      ┆ s) «ente     ┆ []         ┆ Normattiva ┆ 20230317_23G │
# │ io            ┆ creditizio   ┆           ┆ creditizio»  ┆            ┆            ┆ 00035_VIGENZ │
# │               ┆              ┆           ┆ : ((il so…   ┆            ┆            ┆ A_2023…      │
# └───────────────┴──────────────┴───────────┴──────────────┴────────────┴────────────┴──────────────┘

# %%
df.filter(pl.col('label').is_null())
# Out:
# shape: (0, 3)
# ┌───────┬────────┬─────────────────┐
# │ label ┆ showAs ┆ definition_body │
# │ ---   ┆ ---    ┆ ---             │
# │ str   ┆ str    ┆ str             │
# ╞═══════╪════════╪═════════════════╡
# └───────┴────────┴─────────────────┘

# %%
df = df.drop_nulls()
df.select(pl.len())
# Out:
# shape: (1, 1)
# ┌──────┐
# │ len  │
# │ ---  │
# │ u32  │
# ╞══════╡
# │ 9858 │
# └──────┘

# %% [markdown]
# #### Drop duplicates

# %%
df = df.unique()
df.select(pl.len())
# Out:
# shape: (1, 1)
# ┌──────┐
# │ len  │
# │ ---  │
# │ u32  │
# ╞══════╡
# │ 9298 │
# └──────┘

# %%
pl.Config.set_tbl_rows(30)
pl.Config.set_fmt_str_lengths(300)
#df.filter(pl.col('showAs') == 'insect')
df.filter(pl.col('showAs').str.contains('insects'))
# Out:
# shape: (0, 3)
# ┌───────┬────────┬─────────────────┐
# │ label ┆ showAs ┆ definition_body │
# │ ---   ┆ ---    ┆ ---             │
# │ str   ┆ str    ┆ str             │
# ╞═══════╪════════╪═════════════════╡
# └───────┴────────┴─────────────────┘

# %% [markdown]
# ### Unwanted characters
#
# "«", " ", "'"

# %%
df.filter(pl.col('showAs').str.starts_with("normativa di "))
# Out:
# shape: (6, 3)
# ┌──────────────────────────────────┬─────────────────────────────┬─────────────────────────────────┐
# │ label                            ┆ showAs                      ┆ definition_body                 │
# │ ---                              ┆ ---                         ┆ ---                             │
# │ str                              ┆ str                         ┆ str                             │
# ╞══════════════════════════════════╪═════════════════════════════╪═════════════════════════════════╡
# │ #normativaDiArmonizzazioneDellUn ┆ normativa di armonizzazione ┆ la normativa dell'Unione        │
# │ ioneEuropea                      ┆ dell'Unione europea         ┆ europea che armonizza le        │
# │                                  ┆                             ┆ condizioni di                   │
# │                                  ┆                             ┆ commercializzazione dei         │
# │                                  ┆                             ┆ prodotti.                       │
# │ #normativaDiArmonizzazioneDellUn ┆ normativa di armonizzazione ┆ qualunque normativa dell'Unione │
# │ ione                             ┆ dell'Unione                 ┆ che armonizza le condizioni di  │
# │                                  ┆                             ┆ commercializzazione dei         │
# │                                  ┆                             ┆ prodotti;                       │
# │ #normativaDiArmonizzazioneDellUn ┆ normativa di armonizzazione ┆ la normativa dell'Unione        │
# │ ioneEuropea                      ┆ dell'Unione europea         ┆ europea che armonizza le        │
# │                                  ┆                             ┆ condizioni di                   │
# │                                  ┆                             ┆ commercializzazione dei         │
# │                                  ┆                             ┆ prodotti;                       │
# │ #normativaDiArmonizzazioneDellUn ┆ normativa di armonizzazione ┆ la normativa dell'Unione        │
# │ ione                             ┆ dell'Unione                 ┆ europea che armonizza le        │
# │                                  ┆                             ┆ condizioni di                   │
# │                                  ┆                             ┆ commercializzazione dei         │
# │                                  ┆                             ┆ prodotti;                       │
# │ #normativaDiArmonizzazioneDellUn ┆ normativa di armonizzazione ┆ normativa dell'Unione europea   │
# │ ione                             ┆ dell'Unione                 ┆ che armonizza le condizioni di  │
# │                                  ┆                             ┆ commercializzazione del         │
# │                                  ┆                             ┆ dispositivo antiabbandono quale │
# │                                  ┆                             ┆ prodotto;                       │
# │ #normativaDiArmonizzazioneDellUn ┆ normativa di armonizzazione ┆ la normativa dell'Unione che    │
# │ ione                             ┆ dell'Unione                 ┆ armonizza le condizioni di      │
# │                                  ┆                             ┆ commercializzazione dei         │
# │                                  ┆                             ┆ prodotti;                       │
# └──────────────────────────────────┴─────────────────────────────┴─────────────────────────────────┘

# %%
df.group_by('showAs').agg(pl.len()).sort('len', descending=True)
# Out:
# shape: (7_148, 2)
# ┌───────────────────────────────────────────────┬─────┐
# │ showAs                                        ┆ len │
# │ ---                                           ┆ --- │
# │ str                                           ┆ u32 │
# ╞═══════════════════════════════════════════════╪═════╡
# │ competent authority                           ┆ 29  │
# │ manufacturer                                  ┆ 26  │
# │ placing on the market                         ┆ 24  │
# │ autorita' competente                          ┆ 23  │
# │ making available on the market                ┆ 20  │
# │ importer                                      ┆ 19  │
# │ distributor                                   ┆ 18  │
# │ immissione sul mercato                        ┆ 17  │
# │ conformity assessment                         ┆ 17  │
# │ technical specification                       ┆ 16  │
# │ withdrawal                                    ┆ 16  │
# │ fabbricante                                   ┆ 15  │
# │ recall                                        ┆ 15  │
# │ Ministero                                     ┆ 14  │
# │ gestore                                       ┆ 14  │
# │ …                                             ┆ …   │
# │ digital service provider                      ┆ 1   │
# │ carta acquisti                                ┆ 1   │
# │ il «fornitore di servizi di media»            ┆ 1   │
# │ preparazione per il riutilizzo                ┆ 1   │
# │ function                                      ┆ 1   │
# │ open to chimney solid fuel local space heater ┆ 1   │
# │ Fondo carta acquisti                          ┆ 1   │
# │ altri distacchi                               ┆ 1   │
# │ codice dell'istituto dei tessuti dell'UE      ┆ 1   │
# │ indirect heat output                          ┆ 1   │
# │ Consap                                        ┆ 1   │
# │ ex date                                       ┆ 1   │
# │ consulate                                     ┆ 1   │
# │ competent court                               ┆ 1   │
# │ svalutazione sistematica dei risultati        ┆ 1   │
# └───────────────────────────────────────────────┴─────┘

# %% [markdown]
# ---

# %%
from LegalDefAgent.src.config import DB_CONFIG
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 4
#       1 from LegalDefAgent.src.config import DB_CONFIG
# ----> 4 DB_CONFIG.XML_DATA_DIR
#
# AttributeError: 'dict' object has no attribute 'XML_DATA_DIR'

# %%
from LegalDefAgent.src.utils import setup_logging

setup_logging()

builder.build_database()
# Out:
# 2024-12-08 16:20:34,555 - INFO - Extracting definitions from XML files in dataset EurLex...
# 2024-12-08 16:20:54,081 - INFO - Extracting definitions from XML files in dataset Normattiva...
# 2024-12-08 16:21:11,368 - INFO - Extracting definitions from XML files in dataset PDL...
# 2024-12-08 16:21:12,471 - INFO - Extracted definitions from 1348 files. 0 errors out of 22187 files.
# 2024-12-08 16:21:12,801 - DEBUG - https://huggingface.co:443 "GET /api/models/BAAI/bge-m3/revision/main HTTP/1.1" 200 4793
# Fetching 30 files:   0%|          | 0/30 [00:00<?, ?it/s]
# 2024-12-08 16:21:13,918 - INFO - loading existing colbert_linear and sparse_linear---------
# 2024-12-08 16:21:13,991 - INFO - Building vector database...
# 2024-12-08 16:21:14,007 - INFO - Pass in the local path /home/leo/Desktop/dhdk/Master thesis/.project/LegalDefAgent/vec_db/definitions_vectors.db, and run it using milvus-lite
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 10
#       5 from LegalDefAgent.src.utils import setup_logging
#       7 setup_logging()
# ---> 10 builder.build_database()
#
# File ~/Desktop/dhdk/Master thesis/.project/LegalDefAgent/src/retriever/builder.py:35, in build_database(datasets)
#      27     # Process definitions
#      28     #logger.info("Processing extracted definitions...")
#      29     #processor = DefinitionProcessor()
#    (...)
#      32
#      33     # Build vector database
#      34     db_builder = VectorDBBuilder()
# ---> 35     db_builder.build_vector_db(processed_df)
#      37 except Exception as e:
#      38     logger.error(f"Error building database: {e}")
#
# File ~/Desktop/dhdk/Master thesis/.project/LegalDefAgent/src/retriever/embedder.py:101, in VectorDBBuilder.build_vector_db(self, df)
#      99 # Generate embeddings for the batch
#     100 batch_texts = batch_df['definition_text'].to_list()
# --> 101 batch_embeddings = self.ef(batch_texts)
#     103 # Prepare batch data
#     104 batch_data = [
#     105     batch_df['definition_text'].to_list(),
#     106     batch_df['dataset'].to_list(),
#    (...)
#     109     batch_embeddings["dense"],
#     110 ]
#
# File ~/.asdf/installs/python/3.12.6/lib/python3.12/site-packages/milvus_model/hybrid/bge_m3.py:72, in BGEM3EmbeddingFunction.__call__(self, texts)
#      71 def __call__(self, texts: List[str]) -> Dict:
# ---> 72     return self._encode(texts)
#
# File ~/.asdf/installs/python/3.12.6/lib/python3.12/site-packages/milvus_model/hybrid/bge_m3.py:83, in BGEM3EmbeddingFunction._encode(self, texts)
#      82 def _encode(self, texts: List[str]) -> Dict:
# ---> 83     output = self.model.encode(sentences=texts, **self._encode_config)
#      84     results = {}
#      85     if self._encode_config["return_dense"] is True:
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.asdf/installs/python/3.12.6/lib/python3.12/site-packages/FlagEmbedding/bge_m3.py:147, in BGEM3FlagModel.encode(self, sentences, batch_size, max_length, return_dense, return_sparse, return_colbert_vecs)
#     139 sentences_batch = sentences[start_index:start_index + batch_size]
#     140 batch_data = self.tokenizer(
#     141     sentences_batch,
#     142     padding=True,
#    (...)
#     145     max_length=max_length,
#     146 ).to(self.device)
# --> 147 output = self.model(batch_data,
#     148                     return_dense=return_dense,
#     149                     return_sparse=return_sparse,
#     150                     return_colbert=return_colbert_vecs)
#     151 if return_dense:
#     152     all_dense_embeddings.append(output['dense_vecs'].cpu().numpy())
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.asdf/installs/python/3.12.6/lib/python3.12/site-packages/FlagEmbedding/BGE_M3/modeling.py:351, in BGEM3ForInference.forward(self, text_input, return_dense, return_sparse, return_colbert, return_sparse_embedding)
#     343 def forward(self,
#     344             text_input: Dict[str, Tensor] = None,
#     345             return_dense: bool = True,
#     346             return_sparse: bool = False,
#     347             return_colbert: bool = False,
#     348             return_sparse_embedding: bool = False):
#     349     assert return_dense or return_sparse or return_colbert, 'Must choose one or more from `return_colbert`, `return_sparse`, `return_dense` to set `True`!'
# --> 351     last_hidden_state = self.model(**text_input, return_dict=True).last_hidden_state
#     353     output = {}
#     354     if return_dense:
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:834, in XLMRobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     825 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     827 embedding_output = self.embeddings(
#     828     input_ids=input_ids,
#     829     position_ids=position_ids,
#    (...)
#     832     past_key_values_length=past_key_values_length,
#     833 )
# --> 834 encoder_outputs = self.encoder(
#     835     embedding_output,
#     836     attention_mask=extended_attention_mask,
#     837     head_mask=head_mask,
#     838     encoder_hidden_states=encoder_hidden_states,
#     839     encoder_attention_mask=encoder_extended_attention_mask,
#     840     past_key_values=past_key_values,
#     841     use_cache=use_cache,
#     842     output_attentions=output_attentions,
#     843     output_hidden_states=output_hidden_states,
#     844     return_dict=return_dict,
#     845 )
#     846 sequence_output = encoder_outputs[0]
#     847 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:522, in XLMRobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     511     layer_outputs = self._gradient_checkpointing_func(
#     512         layer_module.__call__,
#     513         hidden_states,
#    (...)
#     519         output_attentions,
#     520     )
#     521 else:
# --> 522     layer_outputs = layer_module(
#     523         hidden_states,
#     524         attention_mask,
#     525         layer_head_mask,
#     526         encoder_hidden_states,
#     527         encoder_attention_mask,
#     528         past_key_value,
#     529         output_attentions,
#     530     )
#     532 hidden_states = layer_outputs[0]
#     533 if use_cache:
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:411, in XLMRobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     399 def forward(
#     400     self,
#     401     hidden_states: torch.Tensor,
#    (...)
#     408 ) -> Tuple[torch.Tensor]:
#     409     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     410     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 411     self_attention_outputs = self.attention(
#     412         hidden_states,
#     413         attention_mask,
#     414         head_mask,
#     415         output_attentions=output_attentions,
#     416         past_key_value=self_attn_past_key_value,
#     417     )
#     418     attention_output = self_attention_outputs[0]
#     420     # if decoder, the last output is tuple of self-attn cache
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:347, in XLMRobertaAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     328 def forward(
#     329     self,
#     330     hidden_states: torch.Tensor,
#    (...)
#     336     output_attentions: Optional[bool] = False,
#     337 ) -> Tuple[torch.Tensor]:
#     338     self_outputs = self.self(
#     339         hidden_states,
#     340         attention_mask,
#    (...)
#     345         output_attentions,
#     346     )
# --> 347     attention_output = self.output(self_outputs[0], hidden_states)
#     348     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     349     return outputs
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.12/site-packages/transformers/models/xlm_roberta/modeling_xlm_roberta.py:289, in XLMRobertaSelfOutput.forward(self, hidden_states, input_tensor)
#     288 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 289     hidden_states = self.dense(hidden_states)
#     290     hidden_states = self.dropout(hidden_states)
#     291     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
